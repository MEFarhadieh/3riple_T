# %%
# !pip install --q anndata
# !pip install --q scipy
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 kB 1.2 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
import anndata as ad
from scipy.sparse import csr_matrix
print(ad.__version__)
# Out:
# 0.10.7

# %%
counts = csr_matrix(np.random.poisson(1, size=(100, 2000)), dtype=np.float32)
adata = ad.AnnData(counts)
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000

# %%
adata.X
# Out:
# <100x2000 sparse matrix of type '<class 'numpy.float32'>'
# 	with 126638 stored elements in Compressed Sparse Row format>

# %%
adata.obs_names = [f"Cell_{i:d}" for i in range(adata.n_obs)]
adata.var_names = [f"Gene_{i:d}" for i in range(adata.n_vars)]
print(adata.obs_names[:15])
print(adata.var_names[:15])
# Out:
# Index(['Cell_0', 'Cell_1', 'Cell_2', 'Cell_3', 'Cell_4', 'Cell_5', 'Cell_6',
#        'Cell_7', 'Cell_8', 'Cell_9', 'Cell_10', 'Cell_11', 'Cell_12',
#        'Cell_13', 'Cell_14'],
#       dtype='object')
# Index(['Gene_0', 'Gene_1', 'Gene_2', 'Gene_3', 'Gene_4', 'Gene_5', 'Gene_6',
#        'Gene_7', 'Gene_8', 'Gene_9', 'Gene_10', 'Gene_11', 'Gene_12',
#        'Gene_13', 'Gene_14'],
#       dtype='object')

# %%
adata[["Cell_1", "Cell_10"], ["Gene_5", "Gene_1900", "Gene_32"]]
# Out:
# View of AnnData object with n_obs × n_vars = 2 × 3

# %%
ct = np.random.choice(["B", "T", "Monocyte"], size=(adata.n_obs,))
adata.obs["cell_type"] = pd.Categorical(ct)  # Categoricals are preferred for efficiency
adata.obs
# Out:
#         cell_type
# Cell_0   Monocyte
# Cell_1   Monocyte
# Cell_2          T
# Cell_3   Monocyte
# Cell_4          T
# ...           ...
# Cell_95         B
# Cell_96         B
# Cell_97         B
# Cell_98         B
# Cell_99         B
#
# [100 rows x 1 columns]

# %%
bdata = adata[adata.obs.cell_type == "B"]
bdata
# Out:
# View of AnnData object with n_obs × n_vars = 44 × 2000
#     obs: 'cell_type'

# %%
adata.obsm["X_umap"] = np.random.normal(0, 1, size=(adata.n_obs, 2))
adata.varm["gene_stuff"] = np.random.normal(0, 1, size=(adata.n_vars, 5))
adata.obsm
# Out:
# AxisArrays with keys: X_umap

# %%
adata.layers["log_transformed"] = np.log1p(adata.X)
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2000
#     obs: 'cell_type'
#     obsm: 'X_umap'
#     varm: 'gene_stuff'
#     layers: 'log_transformed'

# %%
bdata.to_df(layer="log_transformed")
# Out:
#            Gene_0    Gene_1    Gene_2    Gene_3    Gene_4    Gene_5    Gene_6  \
# Cell_8   1.098612  0.000000  1.098612  0.693147  0.693147  0.693147  0.000000
# Cell_10  0.000000  0.693147  1.098612  1.098612  0.000000  1.098612  0.000000
# Cell_11  1.098612  0.693147  1.386294  0.000000  0.000000  0.000000  0.693147
# Cell_13  0.000000  0.693147  0.693147  0.693147  0.693147  1.098612  0.693147
# Cell_14  1.098612  0.000000  0.000000  0.000000  1.098612  0.000000  1.386294
# Cell_16  0.693147  0.000000  0.000000  0.693147  0.693147  0.693147  0.000000
# Cell_86   0.693147   1.098612   0.693147   0.000000   0.693147   0.000000
# Cell_95   1.098612   0.000000   1.098612   1.098612   0.000000   0.000000
# Cell_96   1.098612   1.098612   1.098612   0.000000   1.386294   1.098612
# Cell_97   0.693147   0.000000   1.098612   0.693147   1.386294   0.000000
# Cell_98   1.386294   0.693147   0.693147   1.098612   1.098612   0.000000
# Cell_99   0.693147   1.098612   0.000000   0.000000   0.693147   0.000000
#
#          Gene_1999
# Cell_8    0.000000
# Cell_10   0.000000
# Cell_11   0.693147
# Cell_13   0.000000
# Cell_14   0.000000
# Cell_16   0.000000
# Cell_22   0.693147
# Cell_23   1.386294
# Cell_29   1.098612
# Cell_32   1.098612
# Cell_34   0.000000
# Cell_35   0.000000
# Cell_36   0.693147
# Cell_37   1.098612
# Cell_39   1.098612
# Cell_40   1.386294
# Cell_41   0.693147
# Cell_46   1.386294
# Cell_47   0.000000
# Cell_48   0.693147
# Cell_49   0.000000
# Cell_50   1.386294
# Cell_56   1.098612
# Cell_57   0.693147
# Cell_59   1.098612
# Cell_60   0.000000
# Cell_64   1.386294
# Cell_65   0.000000
# Cell_66   0.693147
# Cell_69   0.693147
# Cell_71   0.000000
# Cell_74   0.693147
# Cell_75   1.098612
# Cell_77   0.693147
# Cell_79   0.693147
# Cell_80   1.098612
# Cell_83   1.098612
# Cell_85   1.098612
# Cell_86   0.000000
# Cell_95   0.000000
# Cell_96   0.693147
# Cell_97   1.098612
# Cell_98   0.693147
# Cell_99   1.386294
#
# [44 rows x 2000 columns]

# %%
adata.write('my_results.h5ad', compression="gzip")

# %%
# !sudo apt install tree

# %%
# !tree
# Out:
# .
# ├── my_results.h5ad
# └── sample_data
#     ├── anscombe.json
#     ├── california_housing_test.csv
#     ├── california_housing_train.csv
#     ├── mnist_test.csv
#     ├── mnist_train_small.csv
#     └── README.md
#
# 1 directory, 7 files

# %%
# !sudo apt-get install hdf5-tools

# %%
# !h5ls 'my_results.h5ad'
# Out:
# X                        Group
# layers                   Group
# obs                      Group
# obsm                     Group
# obsp                     Group
# uns                      Group
# var                      Group
# varm                     Group
# varp                     Group

# %%
obs_meta = pd.DataFrame({
        'time_yr': np.random.choice([0, 2, 4, 8], adata.n_obs),
        'subject_id': np.random.choice(['subject 1', 'subject 2', 'subject 4', 'subject 8'], adata.n_obs),
        'instrument_type': np.random.choice(['type a', 'type b'], adata.n_obs),
        'site': np.random.choice(['site x', 'site y'], adata.n_obs),
    },
    index=adata.obs.index,    # these are the same IDs of observations as above!
)
obs_meta
# Out:
#          time_yr subject_id instrument_type    site
# Cell_0         0  subject 1          type a  site x
# Cell_1         8  subject 8          type b  site x
# Cell_2         4  subject 4          type a  site y
# Cell_3         8  subject 1          type a  site y
# Cell_4         2  subject 8          type b  site x
# ...          ...        ...             ...     ...
# Cell_95        0  subject 4          type a  site y
# Cell_96        2  subject 4          type b  site y
# Cell_97        4  subject 8          type a  site y
# Cell_98        0  subject 2          type b  site y
# Cell_99        2  subject 2          type a  site y
#
# [100 rows x 4 columns]

# %%
adata = ad.AnnData(adata.X, obs=obs_meta, var=adata.var)
adata
# Out:
# AnnData object with n_obs × n_vars = 100 × 2001
#     obs: 'time_yr', 'subject_id', 'instrument_type', 'site'
