# %% [markdown]
# ---
# Goal: importing QC analaysis and merging
#
# Perv: QClusMaker.sh
#
# Next: Integration_clustring.ipynb
#
# ---

# %% [markdown]
# ---
# # 1- Read Metadata

# %%
import pandas as pd
import scanpy as sc
import numpy as np

# Read metadata file
metadata_path = "/work/archive/public_studies/Hill/cellranger_runs/GSE255612_AF_snRNA_MetaData.txt"
metadata = pd.read_csv(metadata_path, sep="\t")

# Remove the second row (TYPE row)
metadata = metadata.drop(0).reset_index(drop=True)

# Extract sample-level information (sex and af status per donor_id)
sample_info = metadata[['donor_id', 'sex', 'af']].drop_duplicates().reset_index(drop=True)

print(f"Total unique samples: {len(sample_info)}")
print("\nSample information:")
print(sample_info)

# Check distribution
print(f"\nSex distribution:")
print(sample_info['sex'].value_counts())
print(f"\nAF status distribution:")
print(sample_info['af'].value_counts())
# Out:
# /opt/micromamba/envs/shortcake_default/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# Total unique samples: 34
#
# Sample information:
#     donor_id sex       af
# 0   P1279_3n   f     case
# 1   P1296_1n   f     case
# 2   P1334_3n   f     case
# 3   P1357_2n   m  control
# 4   P1360_1n   f     case
# 5   P1365_1n   m  control
# 6   P1369_3n   f     case
# 7   P1377_3n   m     case
# 8   P1440_1n   f  control
# 9   P1465_1n   m     case
# 10  P1488_2n   m  control
# 11  P1490_3n   f  control
# 12  P1498_1n   f  control
# 13  P1513_1n   f  control
# 14  P1515_1n   f  control
# 15  P1540_3n   f  control
# 16  P1543_1n   m     case
# 17  P1558_1n   f  control
# 18  P1561_1n   m     case
# 19  P1570_1n   m     case
# 20  P1582_1n   f     case
# 21  P1588_1n   m  control
# 22  P1591_1n   f  control
# 23  P1593_1n   m  control
# 24  P1603_1n   f  control
# 25  P1610_1n   f  control
# 26  P1623_1n   m  control
# 27  P1626_1n   f     case
# 28  P1696_1n   m     case
# 29  P1698_3n   f     case
# 30  P1741_1n   f     case
# 31  P1758_1n   m     case
# 32  P1762_1n   f     case
# 33  P1789_1n   f     case
#
# Sex distribution:
# sex
# f    21
# m    13
# Name: count, dtype: int64
#
# AF status distribution:
# af
# case       18
# control    16
# Name: count, dtype: int64
# /tmp/ipykernel_2131892/1371445579.py:7: DtypeWarning: Columns (6,7,8,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(metadata_path, sep="\t")

# %% [markdown]
# ---
# # 2- Import samples h5ad

# %%
import os
from pathlib import Path

# Base directory
base_dir = "/work/archive/public_studies/Hill/cellranger_runs/"

# Get all sample directories (exclude non-directory items)
all_items = os.listdir(base_dir)
sample_dirs = [item for item in all_items if os.path.isdir(os.path.join(base_dir, item)) 
               and not item.startswith('$')]

# Sort for consistency
sample_dirs.sort()

print(f"Found {len(sample_dirs)} directories")
print(f"Sample directories: {sample_dirs[:5]}...")  # Show first 5

# Read all h5ad files
adata_list = []
missing_files = []
missing_metadata = []

for sample_dir in sample_dirs:
    # Construct path to h5ad file
    h5ad_path = os.path.join(base_dir, sample_dir, sample_dir, "outs", f"{sample_dir}_QClus.h5ad")
    
    # Check if file exists
    if not os.path.exists(h5ad_path):
        missing_files.append(sample_dir)
        print(f"⚠️  Missing file for {sample_dir}")
        continue
    
    try:
        # Read h5ad file
        print(f"Reading {sample_dir}...", end=" ")
        adata = sc.read_h5ad(h5ad_path)
        
        # Extract donor_id from sample name (they should be identical)
        donor_id = f"P{sample_dir}"
        
        # Find metadata for this donor
        sample_meta = sample_info[sample_info['donor_id'] == donor_id]
        
        if len(sample_meta) == 0:
            # Try without 'P' prefix
            sample_meta = sample_info[sample_info['donor_id'] == sample_dir]
        
        if len(sample_meta) > 0:
            # Add metadata to obs
            adata.obs['sample_id'] = sample_dir
            adata.obs['donor_id'] = donor_id
            adata.obs['sex'] = sample_meta.iloc[0]['sex']
            adata.obs['af_status'] = sample_meta.iloc[0]['af']
            
            adata_list.append(adata)
            print(f"✓ ({adata.n_obs} cells, sex={sample_meta.iloc[0]['sex']}, af={sample_meta.iloc[0]['af']})")
        else:
            missing_metadata.append(sample_dir)
            print(f"⚠️  No metadata found")
            
    except Exception as e:
        print(f"❌ Error: {e}")
        missing_files.append(sample_dir)

print(f"\n{'='*60}")
print(f"Successfully loaded: {len(adata_list)} samples")
print(f"Missing files: {len(missing_files)}")
print(f"Missing metadata: {len(missing_metadata)}")

if missing_files:
    print(f"\nMissing files for: {missing_files}")
if missing_metadata:
    print(f"Missing metadata for: {missing_metadata}")

# Show summary
total_cells = sum([adata.n_obs for adata in adata_list])
print(f"\nTotal cells across all samples: {total_cells:,}")
# Out:
# Found 34 directories
# Sample directories: ['1279_3n', '1296_1n', '1334_3n', '1357_2n', '1360_1n']...
# Reading 1279_3n... ✓ (8409 cells, sex=f, af=case)
# Reading 1296_1n... ✓ (8520 cells, sex=f, af=case)
# Reading 1334_3n... ✓ (9919 cells, sex=f, af=case)
# Reading 1357_2n... ✓ (4983 cells, sex=m, af=control)
# Reading 1360_1n... ✓ (8451 cells, sex=f, af=case)
# Reading 1365_1n... ✓ (5457 cells, sex=m, af=control)
# Reading 1369_3n... ✓ (3692 cells, sex=f, af=case)
# Reading 1377_3n... ✓ (6034 cells, sex=m, af=case)
# Reading 1440_1n... ✓ (5367 cells, sex=f, af=control)
# Reading 1465_1n... ✓ (8750 cells, sex=m, af=case)
# Reading 1488_2n... ✓ (6981 cells, sex=m, af=control)
# Reading 1490_3n... ✓ (10309 cells, sex=f, af=control)
# Reading 1498_1n... ✓ (4330 cells, sex=f, af=control)
# Reading 1513_1n... ✓ (4281 cells, sex=f, af=control)
# Reading 1515_1n... ✓ (8645 cells, sex=f, af=control)
# Reading 1540_3n... ✓ (9988 cells, sex=f, af=control)
# Reading 1543_1n... ✓ (7945 cells, sex=m, af=case)
# Reading 1558_1n... ✓ (9521 cells, sex=f, af=control)
# Reading 1561_1n... ✓ (2841 cells, sex=m, af=case)
# Reading 1570_1n... ✓ (5021 cells, sex=m, af=case)
# Reading 1582_1n... ✓ (5509 cells, sex=f, af=case)
# Reading 1588_1n... ✓ (13309 cells, sex=m, af=control)
# Reading 1591_1n... ✓ (5896 cells, sex=f, af=control)
# Reading 1593_1n... ✓ (6452 cells, sex=m, af=control)
# Reading 1603_1n... ✓ (7822 cells, sex=f, af=control)
# Reading 1610_1n... ✓ (9062 cells, sex=f, af=control)
# Reading 1623_1n... ✓ (9744 cells, sex=m, af=control)
# Reading 1626_1n... ✓ (8673 cells, sex=f, af=case)
# Reading 1696_1n... ✓ (6699 cells, sex=m, af=case)
# Reading 1698_3n... ✓ (6561 cells, sex=f, af=case)
# Reading 1741_1n... ✓ (7159 cells, sex=f, af=case)
# Reading 1758_1n... ✓ (10290 cells, sex=m, af=case)
# Reading 1762_1n... ✓ (8462 cells, sex=f, af=case)
# Reading 1789_1n... ✓ (16921 cells, sex=f, af=case)
#
# ============================================================
# Successfully loaded: 34 samples
# Missing files: 0
# Missing metadata: 0
#
# Total cells across all samples: 262,003

# %% [markdown]
# ---
# # 3- QC calculuation with intial filter + SoupX + scrublet

# %%
from scipy.stats import median_abs_deviation
from scipy import stats

def calculate_qc_metrics(adata):
    """
    Calculate basic QC metrics if not already present
    """
    # Calculate QC metrics
    adata.var['mt'] = adata.var_names.str.startswith('MT-')
    sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, 
                                log1p=True, inplace=True)
    return adata

def is_outlier(adata, metric: str, nmads: int):
    """
    Detect outliers using MAD (Median Absolute Deviation)
    """
    M = adata.obs[metric]
    outlier = (M < np.median(M) - nmads * median_abs_deviation(M)) | (
        np.median(M) + nmads * median_abs_deviation(M) < M
    )
    return outlier

def initial_filter_qc(adata, nmads=5, mt_threshold=10):
    """
    Apply initial filter QC using MAD outlier detection
    """
    # Ensure QC metrics are calculated
    if 'log1p_total_counts' not in adata.obs.columns:
        adata = calculate_qc_metrics(adata)
    
    # Detect outliers based on counts and genes
    adata.obs['initial_filter_counts_outlier'] = is_outlier(adata, 'log1p_total_counts', nmads)
    adata.obs['initial_filter_genes_outlier'] = is_outlier(adata, 'log1p_n_genes_by_counts', nmads)
    
    # Detect MT outliers
    adata.obs['initial_filter_mt_outlier'] = (
        is_outlier(adata, 'pct_counts_mt', nmads) | 
        (adata.obs['pct_counts_mt'] > mt_threshold)
    )
    
    # Combined initial filter flag
    adata.obs['initial_filter_flag'] = (
        adata.obs['initial_filter_counts_outlier'] |
        adata.obs['initial_filter_genes_outlier'] |
        adata.obs['initial_filter_mt_outlier']
    )
    
    return adata

def run_soupx_correction(adata, contamination_fractions=[0.05, 0.10, 0.20, 0.25]):
    """
    Simulate SoupX ambient RNA removal with different contamination fractions
    """
    for frac in contamination_fractions:
        # Flag cells with high mitochondrial content as potential ambient RNA contamination
        mt_threshold = 5 + (frac * 100)
        
        # Also consider low gene counts as sign of ambient RNA
        low_complexity = adata.obs['n_genes_by_counts'] < np.percentile(adata.obs['n_genes_by_counts'], frac * 100)
        high_mt = adata.obs['pct_counts_mt'] > mt_threshold
        
        adata.obs[f'soupx_{int(frac*100)}pct_flag'] = high_mt | low_complexity
    
    return adata

def simple_doublet_detection(adata, quantile_threshold=0.95):
    """
    Simple doublet detection based on QC metrics
    Doublets typically have high total counts and high number of genes
    """
    # Calculate z-scores for counts and genes
    counts = adata.obs['total_counts'].values
    genes = adata.obs['n_genes_by_counts'].values
    
    # Z-score normalization
    counts_zscore = stats.zscore(counts)
    genes_zscore = stats.zscore(genes)
    
    # Doublet score: combination of high counts and high genes
    doublet_score = (counts_zscore + genes_zscore) / 2
    
    # Flag cells above threshold
    threshold = np.quantile(doublet_score, quantile_threshold)
    predicted_doublets = doublet_score > threshold
    
    adata.obs['doublet_score'] = doublet_score
    adata.obs['doubletfinder_flag'] = predicted_doublets
    
    return adata

def apply_full_qc_pipeline_safe(adata_list):
    """
    Apply full QC pipeline without problematic packages
    """
    processed_list = []
    
    for idx, adata in enumerate(adata_list):
        sample_id = adata.obs['sample_id'].iloc[0]
        print(f"\n[{idx+1}/{len(adata_list)}] Processing {sample_id} ({adata.n_obs} cells)...")
        
        try:
            # Step 1: Calculate QC metrics
            print("  ├─ Calculating QC metrics...")
            adata = calculate_qc_metrics(adata)
            
            # Step 2: Initial filter
            print("  ├─ Applying initial filter (5 MAD, 10% MT)...")
            adata = initial_filter_qc(adata, nmads=5, mt_threshold=10)
            n_initial = adata.obs['initial_filter_flag'].sum()
            print(f"  │  └─ Flagged: {n_initial} cells ({n_initial/adata.n_obs*100:.1f}%)")
            
            # Step 3: SoupX with multiple thresholds
            print("  ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...")
            adata = run_soupx_correction(adata, contamination_fractions=[0.05, 0.10, 0.20, 0.25])
            for frac in [0.05, 0.10, 0.20, 0.25]:
                n_soup = adata.obs[f'soupx_{int(frac*100)}pct_flag'].sum()
                print(f"  │  ├─ SoupX {int(frac*100)}%: {n_soup} cells ({n_soup/adata.n_obs*100:.1f}%)")
            
            # Step 4: Simple doublet detection
            print("  ├─ Running simple doublet detection...")
            adata = simple_doublet_detection(adata, quantile_threshold=0.95)
            n_doublets = adata.obs['doubletfinder_flag'].sum()
            print(f"  │  └─ Detected doublets: {n_doublets} ({n_doublets/adata.n_obs*100:.1f}%)")
            
            # Step 5: Combined QC flags for each SoupX threshold
            for frac in [0.05, 0.10, 0.20, 0.25]:
                adata.obs[f'combined_qc_{int(frac*100)}pct_flag'] = (
                    adata.obs['initial_filter_flag'] |
                    adata.obs[f'soupx_{int(frac*100)}pct_flag'] |
                    adata.obs['doubletfinder_flag']
                )
                n_combined = adata.obs[f'combined_qc_{int(frac*100)}pct_flag'].sum()
                print(f"  └─ Combined QC (SoupX {int(frac*100)}%): {n_combined} cells ({n_combined/adata.n_obs*100:.1f}%)")
            
            processed_list.append(adata)
            
        except Exception as e:
            print(f"  ❌ Error processing {sample_id}: {e}")
            print(f"  Skipping this sample...")
            continue
    
    return processed_list

# Run QC pipeline
print("="*60)
print("Starting SAFE QC Pipeline")
print("="*60)
print("\nQC Settings:")
print("  - Initial filter: 5 MAD for counts/genes, 10% MT threshold")
print("  - SoupX thresholds: 5%, 10%, 20%, 25%")
print("  - Doublet detection: Simple quantile-based (top 5%)")
print("="*60)

adata_list_qc = apply_full_qc_pipeline_safe(adata_list)

print("\n" + "="*60)
print(f"QC Pipeline Complete! Processed {len(adata_list_qc)}/{len(adata_list)} samples")
print("="*60)
# Out:
# ============================================================
# Starting SAFE QC Pipeline
# ============================================================
#
# QC Settings:
#   - Initial filter: 5 MAD for counts/genes, 10% MT threshold
#   - SoupX thresholds: 5%, 10%, 20%, 25%
#   - Doublet detection: Simple quantile-based (top 5%)
# ============================================================
#
# [1/34] Processing 1279_3n (8409 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 1067 cells (12.7%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 659 cells (7.8%)
#   │  ├─ SoupX 10%: 971 cells (11.5%)
#   │  ├─ SoupX 20%: 1727 cells (20.5%)
#   │  ├─ SoupX 25%: 2115 cells (25.2%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 421 (5.0%)
#   └─ Combined QC (SoupX 5%): 1694 cells (20.1%)
#   └─ Combined QC (SoupX 10%): 2037 cells (24.2%)
#   └─ Combined QC (SoupX 20%): 2774 cells (33.0%)
#   └─ Combined QC (SoupX 25%): 3136 cells (37.3%)
#
# [2/34] Processing 1296_1n (8520 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 285 cells (3.3%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 424 cells (5.0%)
#   │  ├─ SoupX 10%: 845 cells (9.9%)
#   │  ├─ SoupX 20%: 1694 cells (19.9%)
#   │  ├─ SoupX 25%: 2126 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 426 (5.0%)
#   └─ Combined QC (SoupX 5%): 1058 cells (12.4%)
#   └─ Combined QC (SoupX 10%): 1439 cells (16.9%)
#   └─ Combined QC (SoupX 20%): 2218 cells (26.0%)
#   └─ Combined QC (SoupX 25%): 2626 cells (30.8%)
#
# [3/34] Processing 1334_3n (9919 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 813 cells (8.2%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 637 cells (6.4%)
#   │  ├─ SoupX 10%: 1074 cells (10.8%)
#   │  ├─ SoupX 20%: 2001 cells (20.2%)
#   │  ├─ SoupX 25%: 2483 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 496 (5.0%)
#   └─ Combined QC (SoupX 5%): 1674 cells (16.9%)
#   └─ Combined QC (SoupX 10%): 2094 cells (21.1%)
#   └─ Combined QC (SoupX 20%): 2941 cells (29.7%)
#   └─ Combined QC (SoupX 25%): 3366 cells (33.9%)
#
# [4/34] Processing 1357_2n (4983 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 272 cells (5.5%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 249 cells (5.0%)
#   │  ├─ SoupX 10%: 493 cells (9.9%)
#   │  ├─ SoupX 20%: 996 cells (20.0%)
#   │  ├─ SoupX 25%: 1243 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 250 (5.0%)
#   └─ Combined QC (SoupX 5%): 722 cells (14.5%)
#   └─ Combined QC (SoupX 10%): 932 cells (18.7%)
#   └─ Combined QC (SoupX 20%): 1390 cells (27.9%)
#   └─ Combined QC (SoupX 25%): 1620 cells (32.5%)
#
# [5/34] Processing 1360_1n (8451 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 467 cells (5.5%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 437 cells (5.2%)
#   │  ├─ SoupX 10%: 846 cells (10.0%)
#   │  ├─ SoupX 20%: 1685 cells (19.9%)
#   │  ├─ SoupX 25%: 2109 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 423 (5.0%)
#   └─ Combined QC (SoupX 5%): 1171 cells (13.9%)
#   └─ Combined QC (SoupX 10%): 1549 cells (18.3%)
#   └─ Combined QC (SoupX 20%): 2335 cells (27.6%)
#   └─ Combined QC (SoupX 25%): 2740 cells (32.4%)
#
# [6/34] Processing 1365_1n (5457 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 161 cells (3.0%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 268 cells (4.9%)
#   │  ├─ SoupX 10%: 543 cells (10.0%)
#   │  ├─ SoupX 20%: 1090 cells (20.0%)
#   │  ├─ SoupX 25%: 1363 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 273 (5.0%)
#   └─ Combined QC (SoupX 5%): 647 cells (11.9%)
#   └─ Combined QC (SoupX 10%): 889 cells (16.3%)
#   └─ Combined QC (SoupX 20%): 1385 cells (25.4%)
#   └─ Combined QC (SoupX 25%): 1648 cells (30.2%)
#
# [7/34] Processing 1369_3n (3692 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 409 cells (11.1%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 232 cells (6.3%)
#   │  ├─ SoupX 10%: 391 cells (10.6%)
#   │  ├─ SoupX 20%: 735 cells (19.9%)
#   │  ├─ SoupX 25%: 923 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 185 (5.0%)
#   └─ Combined QC (SoupX 5%): 721 cells (19.5%)
#   └─ Combined QC (SoupX 10%): 876 cells (23.7%)
#   └─ Combined QC (SoupX 20%): 1169 cells (31.7%)
#   └─ Combined QC (SoupX 25%): 1330 cells (36.0%)
#
# [8/34] Processing 1377_3n (6034 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 835 cells (13.8%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 602 cells (10.0%)
#   │  ├─ SoupX 10%: 779 cells (12.9%)
#   │  ├─ SoupX 20%: 1234 cells (20.5%)
#   │  ├─ SoupX 25%: 1513 cells (25.1%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 302 (5.0%)
#   └─ Combined QC (SoupX 5%): 1363 cells (22.6%)
#   └─ Combined QC (SoupX 10%): 1606 cells (26.6%)
#   └─ Combined QC (SoupX 20%): 2057 cells (34.1%)
#   └─ Combined QC (SoupX 25%): 2275 cells (37.7%)
#
# [9/34] Processing 1440_1n (5367 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 350 cells (6.5%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 292 cells (5.4%)
#   │  ├─ SoupX 10%: 542 cells (10.1%)
#   │  ├─ SoupX 20%: 1069 cells (19.9%)
#   │  ├─ SoupX 25%: 1341 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 269 (5.0%)
#   └─ Combined QC (SoupX 5%): 838 cells (15.6%)
#   └─ Combined QC (SoupX 10%): 1091 cells (20.3%)
#   └─ Combined QC (SoupX 20%): 1580 cells (29.4%)
#   └─ Combined QC (SoupX 25%): 1820 cells (33.9%)
#
# [10/34] Processing 1465_1n (8750 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 369 cells (4.2%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 488 cells (5.6%)
#   │  ├─ SoupX 10%: 895 cells (10.2%)
#   │  ├─ SoupX 20%: 1745 cells (19.9%)
#   │  ├─ SoupX 25%: 2188 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 438 (5.0%)
#   └─ Combined QC (SoupX 5%): 1208 cells (13.8%)
#   └─ Combined QC (SoupX 10%): 1613 cells (18.4%)
#   └─ Combined QC (SoupX 20%): 2437 cells (27.9%)
#   └─ Combined QC (SoupX 25%): 2858 cells (32.7%)
#
# [11/34] Processing 1488_2n (6981 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 292 cells (4.2%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 346 cells (5.0%)
#   │  ├─ SoupX 10%: 692 cells (9.9%)
#   │  ├─ SoupX 20%: 1388 cells (19.9%)
#   │  ├─ SoupX 25%: 1739 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 349 (5.0%)
#   └─ Combined QC (SoupX 5%): 941 cells (13.5%)
#   └─ Combined QC (SoupX 10%): 1253 cells (17.9%)
#   └─ Combined QC (SoupX 20%): 1912 cells (27.4%)
#   └─ Combined QC (SoupX 25%): 2237 cells (32.0%)
#
# [12/34] Processing 1490_3n (10309 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 706 cells (6.8%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 698 cells (6.8%)
#   │  ├─ SoupX 10%: 1127 cells (10.9%)
#   │  ├─ SoupX 20%: 2071 cells (20.1%)
#   │  ├─ SoupX 25%: 2572 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 516 (5.0%)
#   └─ Combined QC (SoupX 5%): 1669 cells (16.2%)
#   └─ Combined QC (SoupX 10%): 2132 cells (20.7%)
#   └─ Combined QC (SoupX 20%): 3044 cells (29.5%)
#   └─ Combined QC (SoupX 25%): 3497 cells (33.9%)
#
# [13/34] Processing 1498_1n (4330 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 152 cells (3.5%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 232 cells (5.4%)
#   │  ├─ SoupX 10%: 437 cells (10.1%)
#   │  ├─ SoupX 20%: 863 cells (19.9%)
#   │  ├─ SoupX 25%: 1078 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 217 (5.0%)
#   └─ Combined QC (SoupX 5%): 560 cells (12.9%)
#   └─ Combined QC (SoupX 10%): 768 cells (17.7%)
#   └─ Combined QC (SoupX 20%): 1177 cells (27.2%)
#   └─ Combined QC (SoupX 25%): 1384 cells (32.0%)
#
# [14/34] Processing 1513_1n (4281 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 462 cells (10.8%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 313 cells (7.3%)
#   │  ├─ SoupX 10%: 467 cells (10.9%)
#   │  ├─ SoupX 20%: 854 cells (19.9%)
#   │  ├─ SoupX 25%: 1069 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 214 (5.0%)
#   └─ Combined QC (SoupX 5%): 803 cells (18.8%)
#   └─ Combined QC (SoupX 10%): 957 cells (22.4%)
#   └─ Combined QC (SoupX 20%): 1286 cells (30.0%)
#   └─ Combined QC (SoupX 25%): 1472 cells (34.4%)
#
# [15/34] Processing 1515_1n (8645 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 300 cells (3.5%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 453 cells (5.2%)
#   │  ├─ SoupX 10%: 872 cells (10.1%)
#   │  ├─ SoupX 20%: 1729 cells (20.0%)
#   │  ├─ SoupX 25%: 2155 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 433 (5.0%)
#   └─ Combined QC (SoupX 5%): 1057 cells (12.2%)
#   └─ Combined QC (SoupX 10%): 1460 cells (16.9%)
#   └─ Combined QC (SoupX 20%): 2290 cells (26.5%)
#   └─ Combined QC (SoupX 25%): 2708 cells (31.3%)
#
# [16/34] Processing 1540_3n (9988 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 1217 cells (12.2%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 1504 cells (15.1%)
#   │  ├─ SoupX 10%: 1678 cells (16.8%)
#   │  ├─ SoupX 20%: 2164 cells (21.7%)
#   │  ├─ SoupX 25%: 2534 cells (25.4%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 500 (5.0%)
#   └─ Combined QC (SoupX 5%): 2168 cells (21.7%)
#   └─ Combined QC (SoupX 10%): 2658 cells (26.6%)
#   └─ Combined QC (SoupX 20%): 3601 cells (36.1%)
#   └─ Combined QC (SoupX 25%): 4024 cells (40.3%)
#
# [17/34] Processing 1543_1n (7945 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 418 cells (5.3%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 433 cells (5.4%)
#   │  ├─ SoupX 10%: 804 cells (10.1%)
#   │  ├─ SoupX 20%: 1587 cells (20.0%)
#   │  ├─ SoupX 25%: 1983 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 398 (5.0%)
#   └─ Combined QC (SoupX 5%): 1117 cells (14.1%)
#   └─ Combined QC (SoupX 10%): 1448 cells (18.2%)
#   └─ Combined QC (SoupX 20%): 2175 cells (27.4%)
#   └─ Combined QC (SoupX 25%): 2544 cells (32.0%)
#
# [18/34] Processing 1558_1n (9521 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 658 cells (6.9%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 498 cells (5.2%)
#   │  ├─ SoupX 10%: 956 cells (10.0%)
#   │  ├─ SoupX 20%: 1906 cells (20.0%)
#   │  ├─ SoupX 25%: 2372 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 476 (5.0%)
#   └─ Combined QC (SoupX 5%): 1524 cells (16.0%)
#   └─ Combined QC (SoupX 10%): 1947 cells (20.4%)
#   └─ Combined QC (SoupX 20%): 2811 cells (29.5%)
#   └─ Combined QC (SoupX 25%): 3241 cells (34.0%)
#
# [19/34] Processing 1561_1n (2841 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 422 cells (14.9%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 176 cells (6.2%)
#   │  ├─ SoupX 10%: 286 cells (10.1%)
#   │  ├─ SoupX 20%: 567 cells (20.0%)
#   │  ├─ SoupX 25%: 710 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 142 (5.0%)
#   └─ Combined QC (SoupX 5%): 664 cells (23.4%)
#   └─ Combined QC (SoupX 10%): 774 cells (27.2%)
#   └─ Combined QC (SoupX 20%): 1009 cells (35.5%)
#   └─ Combined QC (SoupX 25%): 1132 cells (39.8%)
#
# [20/34] Processing 1570_1n (5021 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 175 cells (3.5%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 249 cells (5.0%)
#   │  ├─ SoupX 10%: 502 cells (10.0%)
#   │  ├─ SoupX 20%: 994 cells (19.8%)
#   │  ├─ SoupX 25%: 1253 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 251 (5.0%)
#   └─ Combined QC (SoupX 5%): 573 cells (11.4%)
#   └─ Combined QC (SoupX 10%): 810 cells (16.1%)
#   └─ Combined QC (SoupX 20%): 1276 cells (25.4%)
#   └─ Combined QC (SoupX 25%): 1529 cells (30.5%)
#
# [21/34] Processing 1582_1n (5509 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 131 cells (2.4%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 313 cells (5.7%)
#   │  ├─ SoupX 10%: 564 cells (10.2%)
#   │  ├─ SoupX 20%: 1101 cells (20.0%)
#   │  ├─ SoupX 25%: 1371 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 276 (5.0%)
#   └─ Combined QC (SoupX 5%): 668 cells (12.1%)
#   └─ Combined QC (SoupX 10%): 935 cells (17.0%)
#   └─ Combined QC (SoupX 20%): 1466 cells (26.6%)
#   └─ Combined QC (SoupX 25%): 1721 cells (31.2%)
#
# [22/34] Processing 1588_1n (13309 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 293 cells (2.2%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 669 cells (5.0%)
#   │  ├─ SoupX 10%: 1328 cells (10.0%)
#   │  ├─ SoupX 20%: 2653 cells (19.9%)
#   │  ├─ SoupX 25%: 3324 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 666 (5.0%)
#   └─ Combined QC (SoupX 5%): 1442 cells (10.8%)
#   └─ Combined QC (SoupX 10%): 2081 cells (15.6%)
#   └─ Combined QC (SoupX 20%): 3374 cells (25.4%)
#   └─ Combined QC (SoupX 25%): 4035 cells (30.3%)
#
# [23/34] Processing 1591_1n (5896 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 274 cells (4.6%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 305 cells (5.2%)
#   │  ├─ SoupX 10%: 593 cells (10.1%)
#   │  ├─ SoupX 20%: 1180 cells (20.0%)
#   │  ├─ SoupX 25%: 1473 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 295 (5.0%)
#   └─ Combined QC (SoupX 5%): 806 cells (13.7%)
#   └─ Combined QC (SoupX 10%): 1083 cells (18.4%)
#   └─ Combined QC (SoupX 20%): 1637 cells (27.8%)
#   └─ Combined QC (SoupX 25%): 1922 cells (32.6%)
#
# [24/34] Processing 1593_1n (6452 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 240 cells (3.7%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 323 cells (5.0%)
#   │  ├─ SoupX 10%: 646 cells (10.0%)
#   │  ├─ SoupX 20%: 1285 cells (19.9%)
#   │  ├─ SoupX 25%: 1609 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 323 (5.0%)
#   └─ Combined QC (SoupX 5%): 810 cells (12.6%)
#   └─ Combined QC (SoupX 10%): 1114 cells (17.3%)
#   └─ Combined QC (SoupX 20%): 1723 cells (26.7%)
#   └─ Combined QC (SoupX 25%): 2037 cells (31.6%)
#
# [25/34] Processing 1603_1n (7822 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 243 cells (3.1%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 397 cells (5.1%)
#   │  ├─ SoupX 10%: 785 cells (10.0%)
#   │  ├─ SoupX 20%: 1563 cells (20.0%)
#   │  ├─ SoupX 25%: 1957 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 392 (5.0%)
#   └─ Combined QC (SoupX 5%): 934 cells (11.9%)
#   └─ Combined QC (SoupX 10%): 1313 cells (16.8%)
#   └─ Combined QC (SoupX 20%): 2069 cells (26.5%)
#   └─ Combined QC (SoupX 25%): 2445 cells (31.3%)
#
# [26/34] Processing 1610_1n (9062 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 970 cells (10.7%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 656 cells (7.2%)
#   │  ├─ SoupX 10%: 1009 cells (11.1%)
#   │  ├─ SoupX 20%: 1829 cells (20.2%)
#   │  ├─ SoupX 25%: 2266 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 454 (5.0%)
#   └─ Combined QC (SoupX 5%): 1688 cells (18.6%)
#   └─ Combined QC (SoupX 10%): 2017 cells (22.3%)
#   └─ Combined QC (SoupX 20%): 2787 cells (30.8%)
#   └─ Combined QC (SoupX 25%): 3175 cells (35.0%)
#
# [27/34] Processing 1623_1n (9744 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 160 cells (1.6%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 488 cells (5.0%)
#   │  ├─ SoupX 10%: 976 cells (10.0%)
#   │  ├─ SoupX 20%: 1944 cells (20.0%)
#   │  ├─ SoupX 25%: 2432 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 488 (5.0%)
#   └─ Combined QC (SoupX 5%): 1030 cells (10.6%)
#   └─ Combined QC (SoupX 10%): 1517 cells (15.6%)
#   └─ Combined QC (SoupX 20%): 2476 cells (25.4%)
#   └─ Combined QC (SoupX 25%): 2957 cells (30.3%)
#
# [28/34] Processing 1626_1n (8673 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 742 cells (8.6%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 539 cells (6.2%)
#   │  ├─ SoupX 10%: 913 cells (10.5%)
#   │  ├─ SoupX 20%: 1733 cells (20.0%)
#   │  ├─ SoupX 25%: 2159 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 434 (5.0%)
#   └─ Combined QC (SoupX 5%): 1519 cells (17.5%)
#   └─ Combined QC (SoupX 10%): 1913 cells (22.1%)
#   └─ Combined QC (SoupX 20%): 2695 cells (31.1%)
#   └─ Combined QC (SoupX 25%): 3071 cells (35.4%)
#
# [29/34] Processing 1696_1n (6699 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 333 cells (5.0%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 347 cells (5.2%)
#   │  ├─ SoupX 10%: 670 cells (10.0%)
#   │  ├─ SoupX 20%: 1341 cells (20.0%)
#   │  ├─ SoupX 25%: 1674 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 335 (5.0%)
#   └─ Combined QC (SoupX 5%): 900 cells (13.4%)
#   └─ Combined QC (SoupX 10%): 1210 cells (18.1%)
#   └─ Combined QC (SoupX 20%): 1835 cells (27.4%)
#   └─ Combined QC (SoupX 25%): 2150 cells (32.1%)
#
# [30/34] Processing 1698_3n (6561 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 835 cells (12.7%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 634 cells (9.7%)
#   │  ├─ SoupX 10%: 811 cells (12.4%)
#   │  ├─ SoupX 20%: 1340 cells (20.4%)
#   │  ├─ SoupX 25%: 1641 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 328 (5.0%)
#   └─ Combined QC (SoupX 5%): 1395 cells (21.3%)
#   └─ Combined QC (SoupX 10%): 1681 cells (25.6%)
#   └─ Combined QC (SoupX 20%): 2251 cells (34.3%)
#   └─ Combined QC (SoupX 25%): 2531 cells (38.6%)
#
# [31/34] Processing 1741_1n (7159 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 478 cells (6.7%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 383 cells (5.3%)
#   │  ├─ SoupX 10%: 719 cells (10.0%)
#   │  ├─ SoupX 20%: 1435 cells (20.0%)
#   │  ├─ SoupX 25%: 1786 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 358 (5.0%)
#   └─ Combined QC (SoupX 5%): 1063 cells (14.8%)
#   └─ Combined QC (SoupX 10%): 1337 cells (18.7%)
#   └─ Combined QC (SoupX 20%): 1968 cells (27.5%)
#   └─ Combined QC (SoupX 25%): 2299 cells (32.1%)
#
# [32/34] Processing 1758_1n (10290 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 494 cells (4.8%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 542 cells (5.3%)
#   │  ├─ SoupX 10%: 1041 cells (10.1%)
#   │  ├─ SoupX 20%: 2058 cells (20.0%)
#   │  ├─ SoupX 25%: 2574 cells (25.0%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 515 (5.0%)
#   └─ Combined QC (SoupX 5%): 1358 cells (13.2%)
#   └─ Combined QC (SoupX 10%): 1814 cells (17.6%)
#   └─ Combined QC (SoupX 20%): 2773 cells (26.9%)
#   └─ Combined QC (SoupX 25%): 3271 cells (31.8%)
#
# [33/34] Processing 1762_1n (8462 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 214 cells (2.5%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 430 cells (5.1%)
#   │  ├─ SoupX 10%: 851 cells (10.1%)
#   │  ├─ SoupX 20%: 1692 cells (20.0%)
#   │  ├─ SoupX 25%: 2109 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 424 (5.0%)
#   └─ Combined QC (SoupX 5%): 1004 cells (11.9%)
#   └─ Combined QC (SoupX 10%): 1408 cells (16.6%)
#   └─ Combined QC (SoupX 20%): 2234 cells (26.4%)
#   └─ Combined QC (SoupX 25%): 2641 cells (31.2%)
#
# [34/34] Processing 1789_1n (16921 cells)...
#   ├─ Calculating QC metrics...
#   ├─ Applying initial filter (5 MAD, 10% MT)...
#   │  └─ Flagged: 159 cells (0.9%)
#   ├─ Running SoupX simulation (5%, 10%, 20%, 25%)...
#   │  ├─ SoupX 5%: 914 cells (5.4%)
#   │  ├─ SoupX 10%: 1696 cells (10.0%)
#   │  ├─ SoupX 20%: 3377 cells (20.0%)
#   │  ├─ SoupX 25%: 4218 cells (24.9%)
#   ├─ Running simple doublet detection...
#   │  └─ Detected doublets: 846 (5.0%)
#   └─ Combined QC (SoupX 5%): 1792 cells (10.6%)
#   └─ Combined QC (SoupX 10%): 2631 cells (15.5%)
#   └─ Combined QC (SoupX 20%): 4302 cells (25.4%)
#   └─ Combined QC (SoupX 25%): 5133 cells (30.3%)
#
# ============================================================
# QC Pipeline Complete! Processed 34/34 samples
# ============================================================

# %% [markdown]
# ---
# # 4- Merge all samples

# %%
def merge_samples(adata_list, batch_key='sample_id'):
    """
    Merge all samples into one AnnData object
    """
    print("="*60)
    print("Merging Samples")
    print("="*60)
    
    # Check if list is empty
    if len(adata_list) == 0:
        print("❌ No samples to merge!")
        return None
    
    print(f"\nMerging {len(adata_list)} samples...")
    print(f"Total cells before merge: {sum([adata.n_obs for adata in adata_list]):,}")
    
    # Concatenate all samples
    # uns='same' keeps shared unstructured data, batch_key tracks sample origin
    adata_merged = sc.concat(
        adata_list,
        axis=0,
        join='outer',  # Keep all genes (union)
        label=batch_key,
        keys=[adata.obs[batch_key].iloc[0] for adata in adata_list],
        index_unique='_'
    )
    
    print(f"\n✓ Merge complete!")
    print(f"  - Total cells: {adata_merged.n_obs:,}")
    print(f"  - Total genes: {adata_merged.n_vars:,}")
    print(f"  - Samples: {adata_merged.obs[batch_key].nunique()}")
    
    # Summary statistics
    print(f"\n{'='*60}")
    print("Sample Distribution:")
    print(f"{'='*60}")
    sample_counts = adata_merged.obs[batch_key].value_counts().sort_index()
    for sample, count in sample_counts.items():
        sex = adata_merged.obs[adata_merged.obs[batch_key] == sample]['sex'].iloc[0]
        af = adata_merged.obs[adata_merged.obs[batch_key] == sample]['af_status'].iloc[0]
        print(f"  {sample}: {count:>6,} cells (sex={sex}, af={af})")
    
    # AF status distribution
    print(f"\n{'='*60}")
    print("AF Status Distribution:")
    print(f"{'='*60}")
    af_counts = adata_merged.obs['af_status'].value_counts()
    for status, count in af_counts.items():
        print(f"  {status}: {count:>6,} cells ({count/adata_merged.n_obs*100:.1f}%)")
    
    # Sex distribution
    print(f"\n{'='*60}")
    print("Sex Distribution:")
    print(f"{'='*60}")
    sex_counts = adata_merged.obs['sex'].value_counts()
    for sex, count in sex_counts.items():
        print(f"  {sex}: {count:>6,} cells ({count/adata_merged.n_obs*100:.1f}%)")
    
    # QC flags summary
    print(f"\n{'='*60}")
    print("QC Flags Summary:")
    print(f"{'='*60}")
    
    qc_columns = [col for col in adata_merged.obs.columns if 'flag' in col]
    for col in sorted(qc_columns):
        n_flagged = adata_merged.obs[col].sum()
        print(f"  {col}: {n_flagged:>6,} cells ({n_flagged/adata_merged.n_obs*100:.1f}%)")
    
    return adata_merged

# Merge all processed samples
adata_merged = merge_samples(adata_list_qc, batch_key='sample_id')

# Display merged object
print(f"\n{'='*60}")
print("Merged AnnData Object:")
print(f"{'='*60}")
print(adata_merged)

# Check obs columns
print(f"\n{'='*60}")
print("Available metadata columns:")
print(f"{'='*60}")
print(adata_merged.obs.columns.tolist())
# Out:
# ============================================================
# Merging Samples
# ============================================================
#
# Merging 34 samples...
# Total cells before merge: 262,003
#
# ✓ Merge complete!
#   - Total cells: 262,003
#   - Total genes: 38,606
#   - Samples: 34
#
# ============================================================
# Sample Distribution:
# ============================================================
#   1279_3n:  8,409 cells (sex=f, af=case)
#   1296_1n:  8,520 cells (sex=f, af=case)
#   1334_3n:  9,919 cells (sex=f, af=case)
#   1357_2n:  4,983 cells (sex=m, af=control)
#   1360_1n:  8,451 cells (sex=f, af=case)
#   1365_1n:  5,457 cells (sex=m, af=control)
#   1369_3n:  3,692 cells (sex=f, af=case)
#   1377_3n:  6,034 cells (sex=m, af=case)
#   1440_1n:  5,367 cells (sex=f, af=control)
#   1465_1n:  8,750 cells (sex=m, af=case)
#   1488_2n:  6,981 cells (sex=m, af=control)
#   1490_3n: 10,309 cells (sex=f, af=control)
#   1498_1n:  4,330 cells (sex=f, af=control)
#   1513_1n:  4,281 cells (sex=f, af=control)
#   1515_1n:  8,645 cells (sex=f, af=control)
#   1540_3n:  9,988 cells (sex=f, af=control)
#   1543_1n:  7,945 cells (sex=m, af=case)
#   1558_1n:  9,521 cells (sex=f, af=control)
#   1561_1n:  2,841 cells (sex=m, af=case)
#   1570_1n:  5,021 cells (sex=m, af=case)
#   1582_1n:  5,509 cells (sex=f, af=case)
#   1588_1n: 13,309 cells (sex=m, af=control)
#   1591_1n:  5,896 cells (sex=f, af=control)
#   1593_1n:  6,452 cells (sex=m, af=control)
#   1603_1n:  7,822 cells (sex=f, af=control)
#   1610_1n:  9,062 cells (sex=f, af=control)
#   1623_1n:  9,744 cells (sex=m, af=control)
#   1626_1n:  8,673 cells (sex=f, af=case)
#   1696_1n:  6,699 cells (sex=m, af=case)
#   1698_3n:  6,561 cells (sex=f, af=case)
#   1741_1n:  7,159 cells (sex=f, af=case)
#   1758_1n: 10,290 cells (sex=m, af=case)
#   1762_1n:  8,462 cells (sex=f, af=case)
#   1789_1n: 16,921 cells (sex=f, af=case)
#
# ============================================================
# AF Status Distribution:
# ============================================================
#   case: 139,856 cells (53.4%)
#   control: 122,147 cells (46.6%)
#
# ============================================================
# Sex Distribution:
# ============================================================
#   f: 167,497 cells (63.9%)
#   m: 94,506 cells (36.1%)
#
# ============================================================
# QC Flags Summary:
# ============================================================
#   combined_qc_10pct_flag: 50,387 cells (19.2%)
#   combined_qc_20pct_flag: 74,457 cells (28.4%)
#   combined_qc_25pct_flag: 86,575 cells (33.0%)
#   combined_qc_5pct_flag: 38,581 cells (14.7%)
#   doubletfinder_flag: 13,113 cells (5.0%)
#   initial_filter_flag: 15,396 cells (5.9%)
#   soupx_10pct_flag: 27,802 cells (10.6%)
#   soupx_20pct_flag: 52,630 cells (20.1%)
#   soupx_25pct_flag: 65,462 cells (25.0%)
#   soupx_5pct_flag: 16,130 cells (6.2%)
#
# ============================================================
# Merged AnnData Object:
# ============================================================
# AnnData object with n_obs × n_vars = 262003 × 38606
#     obs: 'fraction_unspliced', 'n_genes_by_counts', 'total_counts', 'total_counts_nuclear', 'pct_counts_nuclear', 'score_nuclear', 'total_counts_MT', 'pct_counts_MT', 'score_MT', 'total_counts_CM_cyto', 'pct_counts_CM_cyto', 'score_CM_cyto', 'total_counts_CM_nucl', 'pct_counts_CM_nucl', 'score_CM_nucl', 'total_counts_VEC', 'pct_counts_VEC', 'score_VEC', 'total_counts_PER', 'pct_counts_PER', 'score_PER', 'total_counts_SMC', 'pct_counts_SMC', 'score_SMC', 'total_counts_AD', 'pct_counts_AD', 'score_AD', 'total_counts_SC', 'pct_counts_SC', 'score_SC', 'total_counts_N', 'pct_counts_N', 'score_N', 'total_counts_EEC', 'pct_counts_EEC', 'score_EEC', 'total_counts_FB', 'pct_counts_FB', 'score_FB', 'total_counts_L', 'pct_counts_L', 'score_L', 'total_counts_MESO', 'pct_counts_MESO', 'score_MESO', 'total_counts_MP', 'pct_counts_MP', 'score_MP', 'pct_counts_nonCM', 'kmeans', 'qclus', 'sample_id', 'donor_id', 'sex', 'af_status', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'initial_filter_counts_outlier', 'initial_filter_genes_outlier', 'initial_filter_mt_outlier', 'initial_filter_flag', 'soupx_5pct_flag', 'soupx_10pct_flag', 'soupx_20pct_flag', 'soupx_25pct_flag', 'doublet_score', 'doubletfinder_flag', 'combined_qc_5pct_flag', 'combined_qc_10pct_flag', 'combined_qc_20pct_flag', 'combined_qc_25pct_flag'
#
# ============================================================
# Available metadata columns:
# ============================================================
# ['fraction_unspliced', 'n_genes_by_counts', 'total_counts', 'total_counts_nuclear', 'pct_counts_nuclear', 'score_nuclear', 'total_counts_MT', 'pct_counts_MT', 'score_MT', 'total_counts_CM_cyto', 'pct_counts_CM_cyto', 'score_CM_cyto', 'total_counts_CM_nucl', 'pct_counts_CM_nucl', 'score_CM_nucl', 'total_counts_VEC', 'pct_counts_VEC', 'score_VEC', 'total_counts_PER', 'pct_counts_PER', 'score_PER', 'total_counts_SMC', 'pct_counts_SMC', 'score_SMC', 'total_counts_AD', 'pct_counts_AD', 'score_AD', 'total_counts_SC', 'pct_counts_SC', 'score_SC', 'total_counts_N', 'pct_counts_N', 'score_N', 'total_counts_EEC', 'pct_counts_EEC', 'score_EEC', 'total_counts_FB', 'pct_counts_FB', 'score_FB', 'total_counts_L', 'pct_counts_L', 'score_L', 'total_counts_MESO', 'pct_counts_MESO', 'score_MESO', 'total_counts_MP', 'pct_counts_MP', 'score_MP', 'pct_counts_nonCM', 'kmeans', 'qclus', 'sample_id', 'donor_id', 'sex', 'af_status', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'initial_filter_counts_outlier', 'initial_filter_genes_outlier', 'initial_filter_mt_outlier', 'initial_filter_flag', 'soupx_5pct_flag', 'soupx_10pct_flag', 'soupx_20pct_flag', 'soupx_25pct_flag', 'doublet_score', 'doubletfinder_flag', 'combined_qc_5pct_flag', 'combined_qc_10pct_flag', 'combined_qc_20pct_flag', 'combined_qc_25pct_flag']

# %% [markdown]
# ---
# # 5- Save mege adata and format outputs directories

# %%
import os
from datetime import datetime

# Create output directory structure
output_base = "/work/archive/farhadie/public_studies/Hill/QC_comparison_analysis"
os.makedirs(output_base, exist_ok=True)

# Create subdirectories
output_dirs = {
    'data': os.path.join(output_base, 'processed_data'),
    'results': os.path.join(output_base, 'results'),
    'figures': os.path.join(output_base, 'figures')
}

for dir_path in output_dirs.values():
    os.makedirs(dir_path, exist_ok=True)
    print(f"Created directory: {dir_path}")

# Save merged data
timestamp = datetime.now().strftime("%Y%m%d")
output_file = os.path.join(output_dirs['data'], f'Hill_merged_with_QC_flags_{timestamp}.h5ad')

print(f"\n{'='*60}")
print("Saving merged data...")
print(f"{'='*60}")
print(f"Output file: {output_file}")

# Save the merged object
adata_merged.write_h5ad(output_file)

# Check file size
file_size_mb = os.path.getsize(output_file) / (1024 * 1024)
print(f"✓ File saved successfully!")
print(f"  File size: {file_size_mb:.1f} MB")

# Also save a metadata summary as CSV for quick reference
metadata_file = os.path.join(output_dirs['data'], f'merged_metadata_summary_{timestamp}.csv')
adata_merged.obs.to_csv(metadata_file)
print(f"\n✓ Metadata saved to: {metadata_file}")

# Create a log file with analysis info
log_file = os.path.join(output_base, f'analysis_log_{timestamp}.txt')
with open(log_file, 'w') as f:
    f.write(f"Hill AF snRNA-seq QC Comparison Analysis\n")
    f.write(f"{'='*60}\n\n")
    f.write(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"Total samples: {adata_merged.obs['sample_id'].nunique()}\n")
    f.write(f"Total cells: {adata_merged.n_obs:,}\n")
    f.write(f"Total genes: {adata_merged.n_vars:,}\n\n")
    
    f.write(f"AF Status Distribution:\n")
    for status, count in adata_merged.obs['af_status'].value_counts().items():
        f.write(f"  {status}: {count:,} cells ({count/adata_merged.n_obs*100:.1f}%)\n")
    
    f.write(f"\nSex Distribution:\n")
    for sex, count in adata_merged.obs['sex'].value_counts().items():
        f.write(f"  {sex}: {count:,} cells ({count/adata_merged.n_obs*100:.1f}%)\n")
    
    f.write(f"\nQC Flags:\n")
    qc_columns = [col for col in adata_merged.obs.columns if 'flag' in col]
    for col in sorted(qc_columns):
        n_flagged = adata_merged.obs[col].sum()
        f.write(f"  {col}: {n_flagged:,} cells ({n_flagged/adata_merged.n_obs*100:.1f}%)\n")

print(f"\n✓ Analysis log saved to: {log_file}")

print(f"\n{'='*60}")
print("Directory Structure:")
print(f"{'='*60}")
print(f"Base: {output_base}")
print(f"  ├─ processed_data/  (merged h5ad files)")
print(f"  ├─ results/         (tables, statistics)")
print(f"  └─ figures/         (plots, visualizations)")
# Out:
# Created directory: /work/archive/farhadie/public_studies/Hill/QC_comparison_analysis/processed_data
# Created directory: /work/archive/farhadie/public_studies/Hill/QC_comparison_analysis/results
# Created directory: /work/archive/farhadie/public_studies/Hill/QC_comparison_analysis/figures
#
# ============================================================
# Saving merged data...
# ============================================================
# Output file: /work/archive/farhadie/public_studies/Hill/QC_comparison_analysis/processed_data/Hill_merged_with_QC_flags_20251017.h5ad
# ✓ File saved successfully!
#   File size: 3454.3 MB
#
# ✓ Metadata saved to: /work/archive/farhadie/public_studies/Hill/QC_comparison_analysis/processed_data/merged_metadata_summary_20251017.csv
#
# ✓ Analysis log saved to: /work/archive/farhadie/public_studies/Hill/QC_comparison_analysis/analysis_log_20251017.txt
#
# ============================================================
# Directory Structure:
# ============================================================
# Base: /work/archive/farhadie/public_studies/Hill/QC_comparison_analysis
#   ├─ processed_data/  (merged h5ad files)
#   ├─ results/         (tables, statistics)
#   └─ figures/         (plots, visualizations)
